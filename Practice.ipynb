# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaikHaarisSaad/Project-1/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Machine Learning**

# %% [markdown]
# One-hot Encoding Dataset Outcones

# %%
from sklearn.preprocessing import OneHotEncoder

data = [
    ["Red"],
    ["Blue"],
    ["Green"],
    ["Red"],
    ["Blue"]
]

encoder = OneHotEncoder()

encoded_data = encoder.fit_transform(data)

print(encoded_data.toarray())
# Out:
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]]
