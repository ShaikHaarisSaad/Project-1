# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaikHaarisSaad/Project-1/blob/main/Pratice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Panda**

# %% [markdown]
# exploratary analysis

# %%
import pandas as pd
ga=pd.read_csv("/content/SteelPlatesFaults.csv")

# %% [markdown]
# Overview of data

# %%
print('first 5 lines of data')
print(ga.head(5))
print('last 5 lines are')
print(ga.tail())
# Out:
# first 5 lines of data
#    X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# 0         42         50     270900     270944           267           17
# 1        645        651    2538079    2538108           108           10
# 2        829        835    1553913    1553931            71            8
# 3        853        860     369370     369415           176           13
# 4       1289       1306     498078     498335          2409           60
#
#    Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# 0           44              24220                     76
# 1           30              11397                     84
# 2           19               7972                     99
# 3           45              18996                     99
# 4          260             246930                     37
#
#    Maximum_of_Luminosity  ...  Orientation_Index  Luminosity_Index  \
# 0                    108  ...             0.8182           -0.2913
# ...

# %% [markdown]
# # print column index method 1

# %%
print('printing column index using columns not list')
print(ga.columns)
# Out:
# printing column index using columns not list
# Index(['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas',
#        'X_Perimeter', 'Y_Perimeter', 'Sum_of_Luminosity',
#        'Minimum_of_Luminosity', 'Maximum_of_Luminosity', 'Length_of_Conveyer',
#        'TypeOfSteel_A300', 'TypeOfSteel_A400', 'Steel_Plate_Thickness',
#        'Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index',
#        'Edges_X_Index', 'Edges_Y_Index', 'Outside_Global_Index', 'LogOfAreas',
#        'Log_X_Index', 'Log_Y_Index', 'Orientation_Index', 'Luminosity_Index',
#        'SigmoidOfAreas', 'Pastry', 'Z_Scratch', 'K_Scatch', 'Stains',
#        'Dirtiness', 'Bumps', 'Other_Faults'],
#       dtype='object')

# %% [markdown]
# # print column index method 2

# %%
print('printing column index using columns not list')
print(list(ga.columns))
# Out:
# printing column index using columns not list
# ['X_Minimum', 'X_Maximum', 'Y_Minimum', 'Y_Maximum', 'Pixels_Areas', 'X_Perimeter', 'Y_Perimeter', 'Sum_of_Luminosity', 'Minimum_of_Luminosity', 'Maximum_of_Luminosity', 'Length_of_Conveyer', 'TypeOfSteel_A300', 'TypeOfSteel_A400', 'Steel_Plate_Thickness', 'Edges_Index', 'Empty_Index', 'Square_Index', 'Outside_X_Index', 'Edges_X_Index', 'Edges_Y_Index', 'Outside_Global_Index', 'LogOfAreas', 'Log_X_Index', 'Log_Y_Index', 'Orientation_Index', 'Luminosity_Index', 'SigmoidOfAreas', 'Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']

# %% [markdown]
# describing the data

# %%
print('describing the data ')
print(ga.describe())
# Out:
# describing the data
#          X_Minimum    X_Maximum     Y_Minimum     Y_Maximum   Pixels_Areas  \
# count  1941.000000  1941.000000  1.941000e+03  1.941000e+03    1941.000000
# mean    571.136012   617.964451  1.650685e+06  1.650739e+06    1893.878413
# std     520.690671   497.627410  1.774578e+06  1.774590e+06    5168.459560
# min       0.000000     4.000000  6.712000e+03  6.724000e+03       2.000000
# 25%      51.000000   192.000000  4.712530e+05  4.712810e+05      84.000000
# 50%     435.000000   467.000000  1.204128e+06  1.204136e+06     174.000000
# 75%    1053.000000  1072.000000  2.183073e+06  2.183084e+06     822.000000
# max    1705.000000  1713.000000  1.298766e+07  1.298769e+07  152655.000000
#
#         X_Perimeter   Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# count   1941.000000   1941.000000       1.941000e+03            1941.000000
# mean     111.855229     82.965997       2.063121e+05              84.548686
# ...

# %% [markdown]
# ### Accessing and filtering

# %% [markdown]
# # Indexing using X minium

# %%
b=ga['X_Minimum']
print(b)
# Out:
# 0         42
# 1        645
# 2        829
# 3        853
# 4       1289
#         ...
# 1936     249
# 1937     144
# 1938     145
# 1939     137
# 1940    1261
# Name: X_Minimum, Length: 1941, dtype: int64

# %%
b=ga['X_Minimum'].values.tolist()
print(b[0:20])
# Out:
# [42, 645, 829, 853, 1289, 430, 413, 190, 330, 74, 106, 505, 46, 581, 451, 669, 156, 90, 82, 1601]

# %% [markdown]
# # LOC

# %%
print('enter the X_Minimum')
print(ga.loc[:,'X_Minimum'])
# Out:
# enter the X_Minimum
# 0         42
# 1        645
# 2        829
# 3        853
# 4       1289
#         ...
# 1936     249
# 1937     144
# 1938     145
# 1939     137
# 1940    1261
# Name: X_Minimum, Length: 1941, dtype: int64

# %%
print('enter the values for X_max')
print(ga.loc[0:15,'X_Minimum'])
# Out:
# enter the values for X_max
# 0       42
# 1      645
# 2      829
# 3      853
# 4     1289
# 5      430
# 6      413
# 7      190
# 8      330
# 9       74
# 10     106
# 11     505
# 12      46
# 13     581
# 14     451
# 15     669
# Name: X_Minimum, dtype: int64

# %% [markdown]
# # Missing data

# %%
print(ga.isna().value_counts())
print(ga.isnull().value_counts())
# Out:
# X_Minimum  X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  Maximum_of_Luminosity  Length_of_Conveyer  TypeOfSteel_A300  TypeOfSteel_A400  Steel_Plate_Thickness  Edges_Index  Empty_Index  Square_Index  Outside_X_Index  Edges_X_Index  Edges_Y_Index  Outside_Global_Index  LogOfAreas  Log_X_Index  Log_Y_Index  Orientation_Index  Luminosity_Index  SigmoidOfAreas  Pastry  Z_Scratch  K_Scatch  Stains  Dirtiness  Bumps  Other_Faults
# ...

# %%
y=ga.dropna()
z=ga.drop_duplicates()
print(len(z))
# Out:
# 1941

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.plot(ga['X_Minimum'])
plt.show()
plt.clf()
